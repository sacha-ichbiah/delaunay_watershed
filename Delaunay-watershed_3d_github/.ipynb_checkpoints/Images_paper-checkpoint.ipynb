# %%
from Wrapper import build_wrapper
from Geometric_utilities_3D import *
from time import time
import skimage.io as io

# %%
filename ="/Users/sachaichbiah/Documents/PHD/Virtual_Embryo/Projects/backup/3D_Embryo_Semantic_Segmentation/Data/Masks_from_meshes/8_cells_artificial_microscopy_picture.tif"
Stack=io.imread(filename).astype(float)#'/Users/sachaichbiah/Documents/PHD/Virtual_Embryo/Gitlab/Trash/delaunay-triangulations/3D_Arabidopsis_Ovules/Tiffs/N_294_final_crop_ds2_predictions.tif',memtest=False)

import scipy 

membrane_prob = Stack

val_thresh=0.7
point_density = 1.0
membrane_prob.shape
# Out:
# (161, 256, 256)

# %%
anisotropy_factor=

# %%
plot_mask_to_evaluate_val_thresh(membrane_prob,val_thresh)

# %%
Seg = build_wrapper(membrane_prob,val_thresh,point_density)
#tesselation,Total_EDT = build_tesselation_and_EDT_from_membrane_prob(membrane_prob,val_thresh,point_density,size_shell=20)
# Out:
# Min_dist 6
# Distance_thresh 5.196152422706632
# 626206
# /Users/sachaichbiah/Documents/PHD/Virtual_Embryo/Projects/C_Elegans_Project/Delaunay-watershed_3d/Geometric_utilities_3D.py:260: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   is_peak = peak_local_max(EDT, min_distance=min_dist,indices=False) # outputs bool image
# Number of points before filtering : 626214
# Number of points after filtering : 4202
# Score before :  13412.815485031175
# Score after :  12146.975319369954
# Number of points before filtering : 4145
# Number of points after filtering : 3112
# Size of the regularization shell 12
# Number of points before filtering : 184631
# Number of points after filtering : 5591
# Number of faces 109948
# Number of border faces 12
# Number of Nodes : 54977  Number of Edges : 109948

# %%
Seg.build_graph()
Seg.watershed_from_local_mins(min_distance = 10,print_info = True, plot_figure = False)
#Seg.watershed_seeded(Coords,print_info=True,plot_figure = False)
# Out:
# Number of Nodes : 54977  Number of Edges : 109948
# Number of Nodes : 17 Number of Edges : 71

# %%
Seg.plot_hist_score()

# %%
def lambda_func(info): 
    return(info['score']<0.075)
Seg.sorted_aggregation(lambda_func,print_info=True)
Seg.plot_cells_polyscope(anisotropy_factor = 256/161)
# Out:
# 9
# Number of Nodes : 9 Number of Edges : 29

# %%
# Out:
# (3107, 3)

# %%
np.shape(Verts)
# Out:
# (8857, 3)

# %%
Seg.node_removal_refinement()
Seg.plot_cells_polyscope()

# %%
nodes_to_del = Seg.node_flipping_refinement()
Seg.plot_cells_polyscope()
# Out:
# Number of problematic Nodes :  88
# Number of problematic Nodes :  88
# [5971, 10280, 16502, 16687, 17793, 17952, 17958, 19677, 19786, 19841, 19842, 19881, 20517, 20572, 20573, 20933, 21204, 21208, 21434, 21435]
# Refinement step finished. Number of nodes flipped : 99
# Number of problematic Nodes :  3
# [25978, 52161, 52160]
# Refinement step finished. Number of nodes flipped : 4
# Number of problematic Nodes :  2
# [52161, 52160]
# Refinement step finished. Number of nodes flipped : 2

# %%
nodes_to_del
# Out:
# []

# %%
Seg.plot_cells_polyscope()

# %%
Seg.export_mesh_text("8_cells_compaction.rec")

# %%
nodes_linked = Seg.Delaunay_Graph.Nodes_Linked_by_Faces
nodes_linked
# Out:
# array([[31183, 31184],
#        [35397, 35406],
#        [31181, 35397],
#        ...,
#        [45330, 45502],
#        [45330, 45332],
#        [45330, 45331]])

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-44ec75acda1f> in <module>
#       7 dict_pb_nodes = {key:[] for key in Seg.Map_end}
#       8 for node_idx in nodes_to_del :
# ----> 9     key = reverse_map[node_idx]
#      10     dict_pb_nodes[key].append(node_idx)
#      11
#
# KeyError: 9012

# %%
nodes_to_del,dict_pb_nodes
# Out:
# ([9012], {0: [], 1: [9012], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []})

# %%
a = np.array([1,2,3,5,4,6,7,8])
#np.remove(a,5)

# %%
c = np.setdiff1d(a,[5])

# %%
c
# Out:
# array([1, 2, 3, 4, 6, 7, 8])
